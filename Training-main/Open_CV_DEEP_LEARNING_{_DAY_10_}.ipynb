# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img=cv2.imread('/content/drive/MyDrive/AI&DS  Dataset/gray scale 1.jpeg',0)
cv2_imshow(img)
img.shape
# Out:
# <PIL.Image.Image image mode=L size=1880x1204>
# (1204, 1880)

# %%
img1=cv2.imread('/content/drive/MyDrive/AI&DS  Dataset/coloe image2.png',1)
cv2_imshow(img1)
img1.shape
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
# (183, 275, 3)

# %%
img2=cv2.imread('/content/drive/MyDrive/AI&DS  Dataset/coloe image2.png',0)
cv2_imshow(img2)
img2.shape
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# (183, 275)

# %%
img_gray=np.zeros((128,128))
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=128x128>

# %%
img_cr=150*np.ones((128,128))
black=np.zeros((64,64))
dark_grey=100*np.ones((64,64))
light_grey=200*np.ones((64,64))
white_grey=255*np.ones((64,64))


img_cr[0:64,0:64]=black
img_cr[0:64,64:128]=dark_grey
img_cr[64:128,0:64]=light_grey
img_cr[64:128,64:128]=white_grey

cv2_imshow(img_cr)
# Out:
# <PIL.Image.Image image mode=L size=128x128>

# %%
img2=cv2.imread('/content/drive/MyDrive/AI&DS  Dataset/coloe image2.png',0)
light_grey=1*np.ones((83,75))

img2[0:83,200:275]=light_grey
cv2_imshow(img2)
img2.shape
# Out:
# <PIL.Image.Image image mode=L size=275x183>
# (183, 275)

# %%
img2=cv2.imread('/content/drive/MyDrive/AI&DS  Dataset/coloe image2.png',0)
hlo=img2[0:183,140:275]
hlo2=img2[0:183,0:140]
hlo[0:183,0:135]=hlo2
cv2.imshow(hlo)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-199367a3e646> in <cell line: 4>()
#       2 hlo=img2[0:183,140:275]
#       3 hlo2=img2[0:183,0:140]
# ----> 4 hlo[0:183,0:135]=hlo2
#       5 cv2.imshow(hlo)
#
# ValueError: could not broadcast input array from shape (183,140) into shape (183,135)

# %%
cv2_imshow(hlo)
# Out:
# <PIL.Image.Image image mode=L size=135x183>

# %%
cv2_imshow(hlo2)
# Out:
# <PIL.Image.Image image mode=L size=140x183>

# %%
img2=cv2.imread('/content/drive/MyDrive/AI&DS  Dataset/coloe image2.png',0)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=275x183>

# %%
# cv2.imwrite('/content/drive/MyDrive/AI&DS  Dataset/my_image.png',img2)
# Out:
# True

# %%
img_vlu=200*np.on((128,128,3))
cv2.imshow(img_vlu)
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-125-032062910254> in <cell line: 2>()
#       1 img_vlu=200*np.ones((128,128,3))
# ----> 2 cv2.imshow(img_vlu)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
